# %%
import pandas as pd
from scipy import stats
import numpy as np
import seaborn as sns
import matplotlib as plt
data = pd.read_csv("DatAkbar.csv",delimiter=",")
cm = sns.light_palette("gold",as_cmap=True)
data.style.background_gradient(cmap=cm)

colum = data.columns.tolist()
for x in colum :
    ds = [x for x in data[x]]
    desc = data[x].describe()
    array = [x for x in desc]
    print ("Detail Kolom ", x)
    print ("Rata-Rata ", array[1])
    print ("Median ", np.median(np.array(ds)))
    print ("Modus : ", stats.mode(ds))
    print ("Standard Deviasi : ", np.std(ds))
    print ("Varian : ", stats.variation(ds))
    print ("Skewness : ", stats.skew(ds))
    print ("Quartil 1 : ", array[4])
    print ("Quartil 2 : ", array[5])
    print ("Quartil 3 : ", array[6])
    sns.distplot(data[x])
    
    print ("\n")
# Out:
# Detail Kolom  17
# Rata-Rata  14.98989898989899
# Median  15.0
# Modus :  ModeResult(mode=array([12]), count=array([12]))
# Standard Deviasi :  3.1446441545083963
# Varian :  0.20978421246383508
# Skewness :  0.08532079753760545
# Quartil 1 :  12.0
# Quartil 2 :  15.0
# Quartil 3 :  18.0
#
#
# Detail Kolom  15
# Rata-Rata  24.949494949494948
# Median  26.0
# Modus :  ModeResult(mode=array([26]), count=array([14]))
# Standard Deviasi :  3.163471234257472
# Varian :  0.12679500088724283
# Skewness :  -0.16427598931293505
# Quartil 1 :  22.0
# Quartil 2 :  26.0
# Quartil 3 :  27.5
#
#
# Detail Kolom  20
# Rata-Rata  14.929292929292929
# Median  15.0
# Modus :  ModeResult(mode=array([17]), count=array([14]))
# Standard Deviasi :  3.166275973514478
# Varian :  0.2120847911894001
# Skewness :  0.09150748211600374
# Quartil 1 :  12.0
# Quartil 2 :  15.0
# Quartil 3 :  17.5
#
#
# Detail Kolom  19
# Rata-Rata  15.191919191919192
# Median  15.0
# Modus :  ModeResult(mode=array([20]), count=array([17]))
# Standard Deviasi :  3.5296057171761523
# Varian :  0.23233441888327067
# Skewness :  -0.012820868650385668
# Quartil 1 :  12.0
# Quartil 2 :  15.0
# Quartil 3 :  19.0
#
#
# Detail Kolom  14
# Rata-Rata  14.727272727272727
# Median  15.0
# Modus :  ModeResult(mode=array([15]), count=array([11]))
# Standard Deviasi :  3.0610560725271254
# Varian :  0.20784948640616285
# Skewness :  0.06620192449898739
# Quartil 1 :  12.0
# Quartil 2 :  15.0
# Quartil 3 :  17.0
